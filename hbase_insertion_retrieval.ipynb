# %% [markdown]
# # Part1: hbase insertion

# %% [markdown]
# ## Python Script/Notebook Setup

# %%
import pandas as pd
import happybase # For HBase connection
from datetime import datetime
import hashlib # For potential salting, though we'll use modulo here

# HBase connection details
HBASE_HOST = 'localhost' # Since Docker maps ports to localhost
HBASE_PORT = 9090        # Default Thrift server port for HBase within the harisekhon/hbase image
                         # Note: The harisekhon image might run Thrift on 9090 by default.
                         # If you have issues connecting, we might need to confirm this port for Thrift.
                         # The docker-compose exposes 9090 (RegionServer UI), but Thrift itself might be on a different internal port
                         # if not explicitly configured or exposed. HappyBase connects to the Thrift server.
                         # Let's assume for now it's accessible via the RegionServer host/port or a default Thrift port.
                         # A common default Thrift port is 9090.

NAMESPACE = 'practice'
TABLE_NAME = 'crimes'
FULL_TABLE_NAME = f'{NAMESPACE}:{TABLE_NAME}'

# Column families (must match what you created in HBase shell)
CF_LOC = 'cf_loc'
CF_CRIME = 'cf_crime'
CF_VICTIM = 'cf_victim'

print("HBase connection parameters set.")
print(f"Target table: {FULL_TABLE_NAME}")
# Out:
# HBase connection parameters set.
# Target table: practice:crimes

# %% [markdown]
# ## Connection to HBase from Python

# %%
def connect_to_hbase():
    """Establishes a connection to HBase."""
    try:
        connection = happybase.Connection(
            host=HBASE_HOST,
            port=HBASE_PORT, # Default HappyBase port if not specified
            autoconnect=True,
            # transport='buffered', # common transport
            # protocol='compact'    # common protocol
        )
        # The autoconnect=True should handle opening.
        # connection.open() # Explicit open if autoconnect is False
        print(f"Successfully connected to HBase at {HBASE_HOST}:{HBASE_PORT}!")
        
        # Optional: List tables to verify connection and that the namespace/table exists
        print("Available tables:", connection.tables())
        return connection
    except Exception as e:
        print(f"Error connecting to HBase: {e}")
        print("Please ensure HBase is running and Thrift server is accessible.")
        print("Common issues: ")
        print("1. HBase Docker container not running or Thrift server not started.")
        print(f"2. Incorrect host ('{HBASE_HOST}') or port ('{HBASE_PORT}') for Thrift server.")
        print("3. Firewall blocking the connection to the Thrift port.")
        return None

connection = connect_to_hbase()
# Out:
# Successfully connected to HBase at localhost:9090!
# Available tables: [b'practice:crimes']

# %% [markdown]
# ## Create Table in Python (Already Done via Shell)

# %%
# This step is optional as the table should already be created via HBase shell.
# If you need to create it from Python:
# def create_hbase_table_if_not_exists(conn, table_name_str, families_dict):
#     if conn:
#         try:
#             tables = conn.tables()
#             if table_name_str.encode('utf-8') not in tables:
#                 print(f"Table '{table_name_str}' not found. Creating it...")
#                 conn.create_table(table_name_str, families_dict)
#                 print(f"Table '{table_name_str}' created successfully with families: {families_dict}")
#             else:
#                 print(f"Table '{table_name_str}' already exists.")
#         except Exception as e:
#             print(f"Error interacting with table '{table_name_str}': {e}")

# families = {
#     CF_LOC: dict(),      # Empty dict for default settings
#     CF_CRIME: dict(),
#     CF_VICTIM: dict()
# }
# if connection:
#    create_hbase_table_if_not_exists(connection, FULL_TABLE_NAME, families)

# %% [markdown]
# ## Load and Clean Data

# %%
def load_and_clean_data(csv_filepath):
    """Loads data from CSV and performs initial cleaning."""
    try:
        df = pd.read_csv(csv_filepath)
        print(f"Dataset '{csv_filepath}' loaded with {df.shape[0]} rows and {df.shape[1]} columns.")
    except FileNotFoundError:
        print(f"Error: File '{csv_filepath}' not found.")
        return None
    
    # --- Column Renaming ---
    original_columns = df.columns.tolist()
    df.columns = [col.lower().replace(' ', '_').replace('-', '_') for col in df.columns]
    # Special handling for 'part_1_2' if it became 'part_1_2' from 'Part 1-2'
    df.columns = [col.replace('part_1_2', 'part_1_2_val') if col == 'part_1_2' else col for col in df.columns]
    renamed_columns = df.columns.tolist()
    print("\nColumns renamed:")
    for orig, new in zip(original_columns, renamed_columns):
        if orig != new:
            print(f"'{orig}' -> '{new}'")

    # --- Date/Time Processing for Rowkey and Storage ---
    # DATE OCC and TIME OCC are crucial for the rowkey.
    # Ensure 'date_occ' is parsed correctly
    try:
        # Assuming 'date_occ' format is like 'MM/DD/YYYY hh:mm:ss AM/PM' or just 'MM/DD/YYYY'
        # If it's just 'MM/DD/YYYY', pd.to_datetime will handle it.
        # If it has time, we need to be careful or split it.
        # Let's assume the original CSV 'DATE OCC' is the primary date.
        df['parsed_date_occ'] = pd.to_datetime(df['date_occ'], errors='coerce')

        # Extract components for rowkey
        df['year_occ'] = df['parsed_date_occ'].dt.year
        df['month_occ'] = df['parsed_date_occ'].dt.month
        # df['day_occ'] = df['parsed_date_occ'].dt.day # Not used in current rowkey design, but good to have

        # Handle 'time_occ' (integer like 1830)
        # Convert to string, pad with leading zeros to ensure 4 digits for HHMM
        df['time_occ_str'] = df['time_occ'].astype(str).str.zfill(4)
        df['hour_occ'] = df['time_occ_str'].str.slice(0, 2)
        # df['minute_occ'] = df['time_occ_str'].str.slice(2, 4) # Not used in current rowkey

    except Exception as e:
        print(f"Error parsing date/time columns: {e}")
        print("Please check 'date_occ' and 'time_occ' formats.")
        # Fill with placeholder if parsing fails to avoid issues later, though this should be addressed
        df['year_occ'] = 1900
        df['month_occ'] = 1
        # df['day_occ'] = 1
        df['hour_occ'] = '00'

    # --- Prepare Catalog for Column Families ---
    # This maps your DataFrame columns to HBase column qualifiers with their families
    column_family_mapping = {
        # cf_loc
        'area_name': CF_LOC,
        'rpt_dist_no': CF_LOC,
        'premis_cd': CF_LOC,
        'premis_desc': CF_LOC,
        'location': CF_LOC,
        'cross_street': CF_LOC,
        'lat': CF_LOC,
        'lon': CF_LOC,
        # cf_crime
        'crm_cd': CF_CRIME,
        'crm_cd_desc': CF_CRIME,
        'part_1_2_val': CF_CRIME, # Renamed from 'part 1-2'
        'mocodes': CF_CRIME,
        'weapon_used_cd': CF_CRIME,
        'weapon_desc': CF_CRIME,
        'status': CF_CRIME,
        'status_desc': CF_CRIME,
        'crm_cd_1': CF_CRIME,
        'crm_cd_2': CF_CRIME,
        'crm_cd_3': CF_CRIME,
        'crm_cd_4': CF_CRIME,
        'date_rptd': CF_CRIME, # Original date reported string
        'date_occ': CF_CRIME,  # Original date occurred string
        'time_occ': CF_CRIME,  # Original time occurred integer
        # cf_victim
        'vict_age': CF_VICTIM,
        'vict_sex': CF_VICTIM,
        'vict_descent': CF_VICTIM,
    }
    # DR_NO, year_occ, month_occ, area are used for rowkey, not directly as columns here
    # (unless you also want to store them as distinct columns, which is redundant if in rowkey)

    print("\nData cleaning and preparation complete (excluding rowkey generation for now).")
    return df, column_family_mapping

# Load the data
csv_file = 'Crime_Data_from_2020_to_Present.csv' # Make sure this path is correct
df_crimes, cf_mapping = load_and_clean_data(csv_file)

if df_crimes is not None:
    print("\nSample of processed DataFrame headers:")
    print(df_crimes.head(2))
    print("\nYear OCC unique values:", df_crimes['year_occ'].unique())
    print("Month OCC unique values:", df_crimes['month_occ'].unique())
    print("Area unique values:", df_crimes['area'].unique()) # 'area' is the numeric area code column
# Out:
# Dataset 'Crime_Data_from_2020_to_Present.csv' loaded with 1005091 rows and 28 columns.
#
# Columns renamed:
# 'DR_NO' -> 'dr_no'
# 'Date Rptd' -> 'date_rptd'
# 'DATE OCC' -> 'date_occ'
# 'TIME OCC' -> 'time_occ'
# 'AREA' -> 'area'
# 'AREA NAME' -> 'area_name'
# 'Rpt Dist No' -> 'rpt_dist_no'
# 'Part 1-2' -> 'part_1_2_val'
# 'Crm Cd' -> 'crm_cd'
# 'Crm Cd Desc' -> 'crm_cd_desc'
# 'Mocodes' -> 'mocodes'
# 'Vict Age' -> 'vict_age'
# 'Vict Sex' -> 'vict_sex'
# 'Vict Descent' -> 'vict_descent'
# 'Premis Cd' -> 'premis_cd'
# 'Premis Desc' -> 'premis_desc'
# 'Weapon Used Cd' -> 'weapon_used_cd'
# 'Weapon Desc' -> 'weapon_desc'
# 'Status' -> 'status'
# 'Status Desc' -> 'status_desc'
# 'Crm Cd 1' -> 'crm_cd_1'
# 'Crm Cd 2' -> 'crm_cd_2'
# 'Crm Cd 3' -> 'crm_cd_3'
# 'Crm Cd 4' -> 'crm_cd_4'
# 'LOCATION' -> 'location'
# 'Cross Street' -> 'cross_street'
# 'LAT' -> 'lat'
# 'LON' -> 'lon'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7276\500485185.py:29: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['parsed_date_occ'] = pd.to_datetime(df['date_occ'], errors='coerce')
# Data cleaning and preparation complete (excluding rowkey generation for now).
#
# Sample of processed DataFrame headers:
#        dr_no               date_rptd                date_occ  time_occ  area  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
#
#   area_name  rpt_dist_no  part_1_2_val  crm_cd            crm_cd_desc  ...  \
# 0  Wilshire          784             1     510       VEHICLE - STOLEN  ...
# 1   Central          182             1     330  BURGLARY FROM VEHICLE  ...
#
#   crm_cd_4                                 location cross_street      lat  \
# 0      NaN  1900 S  LONGWOOD                     AV          NaN  34.0375
# 1      NaN  1000 S  FLOWER                       ST          NaN  34.0444
#
#         lon parsed_date_occ  year_occ month_occ time_occ_str hour_occ
# 0 -118.3506      2020-03-01      2020         3         2130       21
# 1 -118.2628      2020-02-08      2020         2         1800       18
#
# [2 rows x 33 columns]
#
# Year OCC unique values: [2020 2021 2022 2023 2024 2025]
# Month OCC unique values: [ 3  2 11  9  5  7 12  6  8  1  4 10]
# Area unique values: [ 7  1  3  9  4  2 13 11 12  6  5 10  8 15 14 17 19 18 20 16 21]

# %% [markdown]
# ## Implement Rowkey Generation and Data Push Function

# %%
def generate_row_key(row):
    """
    Generates the HBase rowkey: SALT_YEAR_MONTH_AREACODE_DRNO
    SALT: DR_NO % 100 (2 digits, zero-padded)
    YEAR: 4-digit year
    MONTH: 2-digit month (zero-padded)
    AREACODE: 'area' column value (2 digits, zero-padded)
    DRNO: dr_no
    """
    try:
        # Ensure necessary fields are not NaN/None before processing
        if pd.isna(row['dr_no']) or pd.isna(row['year_occ']) or \
        pd.isna(row['month_occ']) or pd.isna(row['area']):
            return None # Skip rows with missing key components

        dr_no = int(row['dr_no'])
        salt = str(dr_no % 100).zfill(2) # 2-digit salt
        
        year = str(int(row['year_occ']))
        month = str(int(row['month_occ'])).zfill(2) # 2-digit month
        
        areacode = str(int(row['area'])).zfill(2) # 2-digit area code

        # Rowkey: SALT_YEAR_MONTH_AREACODE_DRNO
        row_key_str = f"{salt}_{year}_{month}_{areacode}_{dr_no}"
        return row_key_str.encode('utf-8') # HBase rowkeys are bytes
    except Exception as e:
        # print(f"Error generating rowkey for DR_NO {row.get('dr_no', 'Unknown')}: {e}")
        return None


def push_data_to_hbase(conn, df, table_name_str, col_family_map, batch_size=1000, row_limit=500000):
    """
    Pushes data from DataFrame to HBase table, skipping NA values for cells.
    """
    if not conn or df is None:
        print("No HBase connection or DataFrame is None. Aborting push.")
        return

    try:
        table = conn.table(table_name_str)
        print(f"\nStarting data insertion into '{table_name_str}'...")
        
        success_count = 0
        error_count = 0
        skipped_count = 0
        
        # Use table.batch() for more efficient writes
        with table.batch(batch_size=batch_size) as b:
            for index, row in df.head(row_limit).iterrows(): # Process only the first row_limit rows
                row_key = generate_row_key(row)

                if row_key is None:
                    skipped_count +=1
                    if skipped_count % (batch_size * 10) == 0 : # Print progress occasionally for skipped
                        print(f"Skipped {skipped_count} rows due to missing key components...")
                    continue

                data_to_insert = {}
                for col_name_df, cf_name_hbase in col_family_map.items():
                    if col_name_df in row and pd.notna(row[col_name_df]):
                        # Ensure value is string for HBase, convert if necessary
                        value = str(row[col_name_df])
                        # Construct fully qualified column name: cf:qualifier
                        hbase_col_qualifier = f"{cf_name_hbase}:{col_name_df}"
                        data_to_insert[hbase_col_qualifier.encode('utf-8')] = value.encode('utf-8')
                
                if data_to_insert: # Only insert if there's some data besides key
                    try:
                        b.put(row_key, data_to_insert)
                        success_count += 1
                    except Exception as e_put:
                        print(f"Error inserting row with key {row_key.decode('utf-8', errors='ignore')}: {e_put}")
                        error_count += 1
                else:
                    skipped_count +=1 # Also counts as skipped if no actual data columns to insert

                if (index + 1) % batch_size == 0:
                    print(f"Processed {index + 1} rows. Inserted: {success_count}, Errors: {error_count}, Skipped: {skipped_count}")
            
            # The batch sends automatically when it fills or at the end of the 'with' block.
            # If any rows are left in the batch and not sent, ensure they are.
            # (HappyBase batch context manager handles this)

        print(f"\nData insertion summary for the first {row_limit} rows:")
        print(f"Successfully inserted rows: {success_count}")
        print(f"Rows with errors during put: {error_count}")
        print(f"Rows skipped (missing key components or no data): {skipped_count}")

    except Exception as e:
        print(f"An error occurred during the batch insertion process: {e}")

# --- Trigger the insertion ---
if connection and df_crimes is not None:
    push_data_to_hbase(connection, df_crimes, FULL_TABLE_NAME, cf_mapping, row_limit=500000) # Push first 500k
else:
    if not connection:
        print("Cannot push data: No HBase connection.")
    if df_crimes is None:
        print("Cannot push data: DataFrame not loaded.")
# Out:
# Starting data insertion into 'practice:crimes'...
# Processed 1000 rows. Inserted: 1000, Errors: 0, Skipped: 0
# Processed 2000 rows. Inserted: 2000, Errors: 0, Skipped: 0
# Processed 3000 rows. Inserted: 3000, Errors: 0, Skipped: 0
# Processed 4000 rows. Inserted: 4000, Errors: 0, Skipped: 0
# Processed 5000 rows. Inserted: 5000, Errors: 0, Skipped: 0
# Processed 6000 rows. Inserted: 6000, Errors: 0, Skipped: 0
# Processed 7000 rows. Inserted: 7000, Errors: 0, Skipped: 0
# Processed 8000 rows. Inserted: 8000, Errors: 0, Skipped: 0
# Processed 9000 rows. Inserted: 9000, Errors: 0, Skipped: 0
# Processed 10000 rows. Inserted: 10000, Errors: 0, Skipped: 0
# Processed 11000 rows. Inserted: 11000, Errors: 0, Skipped: 0
# Processed 12000 rows. Inserted: 12000, Errors: 0, Skipped: 0
# Processed 13000 rows. Inserted: 13000, Errors: 0, Skipped: 0
# Processed 14000 rows. Inserted: 14000, Errors: 0, Skipped: 0
# Processed 15000 rows. Inserted: 15000, Errors: 0, Skipped: 0
# Processed 16000 rows. Inserted: 16000, Errors: 0, Skipped: 0
# Processed 17000 rows. Inserted: 17000, Errors: 0, Skipped: 0
# Processed 18000 rows. Inserted: 18000, Errors: 0, Skipped: 0
# Processed 19000 rows. Inserted: 19000, Errors: 0, Skipped: 0
# Processed 20000 rows. Inserted: 20000, Errors: 0, Skipped: 0
# Processed 21000 rows. Inserted: 21000, Errors: 0, Skipped: 0
# Processed 22000 rows. Inserted: 22000, Errors: 0, Skipped: 0
# Processed 23000 rows. Inserted: 23000, Errors: 0, Skipped: 0
# Processed 24000 rows. Inserted: 24000, Errors: 0, Skipped: 0
# Processed 25000 rows. Inserted: 25000, Errors: 0, Skipped: 0
# Processed 26000 rows. Inserted: 26000, Errors: 0, Skipped: 0
# Processed 27000 rows. Inserted: 27000, Errors: 0, Skipped: 0
# Processed 28000 rows. Inserted: 28000, Errors: 0, Skipped: 0
# Processed 29000 rows. Inserted: 29000, Errors: 0, Skipped: 0
# Processed 30000 rows. Inserted: 30000, Errors: 0, Skipped: 0
# Processed 31000 rows. Inserted: 31000, Errors: 0, Skipped: 0
# Processed 32000 rows. Inserted: 32000, Errors: 0, Skipped: 0
# Processed 33000 rows. Inserted: 33000, Errors: 0, Skipped: 0
# Processed 34000 rows. Inserted: 34000, Errors: 0, Skipped: 0
# Processed 35000 rows. Inserted: 35000, Errors: 0, Skipped: 0
# Processed 36000 rows. Inserted: 36000, Errors: 0, Skipped: 0
# Processed 37000 rows. Inserted: 37000, Errors: 0, Skipped: 0
# Processed 38000 rows. Inserted: 38000, Errors: 0, Skipped: 0
# Processed 39000 rows. Inserted: 39000, Errors: 0, Skipped: 0
# Processed 40000 rows. Inserted: 40000, Errors: 0, Skipped: 0
# Processed 41000 rows. Inserted: 41000, Errors: 0, Skipped: 0
# Processed 42000 rows. Inserted: 42000, Errors: 0, Skipped: 0
# Processed 43000 rows. Inserted: 43000, Errors: 0, Skipped: 0
# Processed 44000 rows. Inserted: 44000, Errors: 0, Skipped: 0
# Processed 45000 rows. Inserted: 45000, Errors: 0, Skipped: 0
# Processed 46000 rows. Inserted: 46000, Errors: 0, Skipped: 0
# Processed 47000 rows. Inserted: 47000, Errors: 0, Skipped: 0
# Processed 48000 rows. Inserted: 48000, Errors: 0, Skipped: 0
# Processed 49000 rows. Inserted: 49000, Errors: 0, Skipped: 0
# Processed 50000 rows. Inserted: 50000, Errors: 0, Skipped: 0
# Processed 51000 rows. Inserted: 51000, Errors: 0, Skipped: 0
# Processed 52000 rows. Inserted: 52000, Errors: 0, Skipped: 0
# Processed 53000 rows. Inserted: 53000, Errors: 0, Skipped: 0
# Processed 54000 rows. Inserted: 54000, Errors: 0, Skipped: 0
# Processed 55000 rows. Inserted: 55000, Errors: 0, Skipped: 0
# Processed 56000 rows. Inserted: 56000, Errors: 0, Skipped: 0
# Processed 57000 rows. Inserted: 57000, Errors: 0, Skipped: 0
# Processed 58000 rows. Inserted: 58000, Errors: 0, Skipped: 0
# Processed 59000 rows. Inserted: 59000, Errors: 0, Skipped: 0
# Processed 60000 rows. Inserted: 60000, Errors: 0, Skipped: 0
# Processed 61000 rows. Inserted: 61000, Errors: 0, Skipped: 0
# Processed 62000 rows. Inserted: 62000, Errors: 0, Skipped: 0
# Processed 63000 rows. Inserted: 63000, Errors: 0, Skipped: 0
# Processed 64000 rows. Inserted: 64000, Errors: 0, Skipped: 0
# Processed 65000 rows. Inserted: 65000, Errors: 0, Skipped: 0
# Processed 66000 rows. Inserted: 66000, Errors: 0, Skipped: 0
# Processed 67000 rows. Inserted: 67000, Errors: 0, Skipped: 0
# Processed 68000 rows. Inserted: 68000, Errors: 0, Skipped: 0
# Processed 69000 rows. Inserted: 69000, Errors: 0, Skipped: 0
# Processed 70000 rows. Inserted: 70000, Errors: 0, Skipped: 0
# Processed 71000 rows. Inserted: 71000, Errors: 0, Skipped: 0
# Processed 72000 rows. Inserted: 72000, Errors: 0, Skipped: 0
# Processed 73000 rows. Inserted: 73000, Errors: 0, Skipped: 0
# Processed 74000 rows. Inserted: 74000, Errors: 0, Skipped: 0
# Processed 75000 rows. Inserted: 75000, Errors: 0, Skipped: 0
# Processed 76000 rows. Inserted: 76000, Errors: 0, Skipped: 0
# Processed 77000 rows. Inserted: 77000, Errors: 0, Skipped: 0
# Processed 78000 rows. Inserted: 78000, Errors: 0, Skipped: 0
# Processed 79000 rows. Inserted: 79000, Errors: 0, Skipped: 0
# Processed 80000 rows. Inserted: 80000, Errors: 0, Skipped: 0
# Processed 81000 rows. Inserted: 81000, Errors: 0, Skipped: 0
# Processed 82000 rows. Inserted: 82000, Errors: 0, Skipped: 0
# Processed 83000 rows. Inserted: 83000, Errors: 0, Skipped: 0
# Processed 84000 rows. Inserted: 84000, Errors: 0, Skipped: 0
# Processed 85000 rows. Inserted: 85000, Errors: 0, Skipped: 0
# Processed 86000 rows. Inserted: 86000, Errors: 0, Skipped: 0
# Processed 87000 rows. Inserted: 87000, Errors: 0, Skipped: 0
# Processed 88000 rows. Inserted: 88000, Errors: 0, Skipped: 0
# Processed 89000 rows. Inserted: 89000, Errors: 0, Skipped: 0
# Processed 90000 rows. Inserted: 90000, Errors: 0, Skipped: 0
# Processed 91000 rows. Inserted: 91000, Errors: 0, Skipped: 0
# Processed 92000 rows. Inserted: 92000, Errors: 0, Skipped: 0
# Processed 93000 rows. Inserted: 93000, Errors: 0, Skipped: 0
# Processed 94000 rows. Inserted: 94000, Errors: 0, Skipped: 0
# Processed 95000 rows. Inserted: 95000, Errors: 0, Skipped: 0
# Processed 96000 rows. Inserted: 96000, Errors: 0, Skipped: 0
# Processed 97000 rows. Inserted: 97000, Errors: 0, Skipped: 0
# Processed 98000 rows. Inserted: 98000, Errors: 0, Skipped: 0
# Processed 99000 rows. Inserted: 99000, Errors: 0, Skipped: 0
# Processed 100000 rows. Inserted: 100000, Errors: 0, Skipped: 0
# Processed 101000 rows. Inserted: 101000, Errors: 0, Skipped: 0
# Processed 102000 rows. Inserted: 102000, Errors: 0, Skipped: 0
# Processed 103000 rows. Inserted: 103000, Errors: 0, Skipped: 0
# Processed 104000 rows. Inserted: 104000, Errors: 0, Skipped: 0
# Processed 105000 rows. Inserted: 105000, Errors: 0, Skipped: 0
# Processed 106000 rows. Inserted: 106000, Errors: 0, Skipped: 0
# Processed 107000 rows. Inserted: 107000, Errors: 0, Skipped: 0
# Processed 108000 rows. Inserted: 108000, Errors: 0, Skipped: 0
# Processed 109000 rows. Inserted: 109000, Errors: 0, Skipped: 0
# Processed 110000 rows. Inserted: 110000, Errors: 0, Skipped: 0
# Processed 111000 rows. Inserted: 111000, Errors: 0, Skipped: 0
# Processed 112000 rows. Inserted: 112000, Errors: 0, Skipped: 0
# Processed 113000 rows. Inserted: 113000, Errors: 0, Skipped: 0
# Processed 114000 rows. Inserted: 114000, Errors: 0, Skipped: 0
# Processed 115000 rows. Inserted: 115000, Errors: 0, Skipped: 0
# Processed 116000 rows. Inserted: 116000, Errors: 0, Skipped: 0
# Processed 117000 rows. Inserted: 117000, Errors: 0, Skipped: 0
# Processed 118000 rows. Inserted: 118000, Errors: 0, Skipped: 0
# Processed 119000 rows. Inserted: 119000, Errors: 0, Skipped: 0
# Processed 120000 rows. Inserted: 120000, Errors: 0, Skipped: 0
# Processed 121000 rows. Inserted: 121000, Errors: 0, Skipped: 0
# Processed 122000 rows. Inserted: 122000, Errors: 0, Skipped: 0
# Processed 123000 rows. Inserted: 123000, Errors: 0, Skipped: 0
# Processed 124000 rows. Inserted: 124000, Errors: 0, Skipped: 0
# Processed 125000 rows. Inserted: 125000, Errors: 0, Skipped: 0
# Processed 126000 rows. Inserted: 126000, Errors: 0, Skipped: 0
# Processed 127000 rows. Inserted: 127000, Errors: 0, Skipped: 0
# Processed 128000 rows. Inserted: 128000, Errors: 0, Skipped: 0
# Processed 129000 rows. Inserted: 129000, Errors: 0, Skipped: 0
# Processed 130000 rows. Inserted: 130000, Errors: 0, Skipped: 0
# Processed 131000 rows. Inserted: 131000, Errors: 0, Skipped: 0
# Processed 132000 rows. Inserted: 132000, Errors: 0, Skipped: 0
# Processed 133000 rows. Inserted: 133000, Errors: 0, Skipped: 0
# Processed 134000 rows. Inserted: 134000, Errors: 0, Skipped: 0
# Processed 135000 rows. Inserted: 135000, Errors: 0, Skipped: 0
# Processed 136000 rows. Inserted: 136000, Errors: 0, Skipped: 0
# Processed 137000 rows. Inserted: 137000, Errors: 0, Skipped: 0
# Processed 138000 rows. Inserted: 138000, Errors: 0, Skipped: 0
# Processed 139000 rows. Inserted: 139000, Errors: 0, Skipped: 0
# Processed 140000 rows. Inserted: 140000, Errors: 0, Skipped: 0
# Processed 141000 rows. Inserted: 141000, Errors: 0, Skipped: 0
# Processed 142000 rows. Inserted: 142000, Errors: 0, Skipped: 0
# Processed 143000 rows. Inserted: 143000, Errors: 0, Skipped: 0
# Processed 144000 rows. Inserted: 144000, Errors: 0, Skipped: 0
# Processed 145000 rows. Inserted: 145000, Errors: 0, Skipped: 0
# Processed 146000 rows. Inserted: 146000, Errors: 0, Skipped: 0
# Processed 147000 rows. Inserted: 147000, Errors: 0, Skipped: 0
# Processed 148000 rows. Inserted: 148000, Errors: 0, Skipped: 0
# Processed 149000 rows. Inserted: 149000, Errors: 0, Skipped: 0
# Processed 150000 rows. Inserted: 150000, Errors: 0, Skipped: 0
# Processed 151000 rows. Inserted: 151000, Errors: 0, Skipped: 0
# Processed 152000 rows. Inserted: 152000, Errors: 0, Skipped: 0
# Processed 153000 rows. Inserted: 153000, Errors: 0, Skipped: 0
# Processed 154000 rows. Inserted: 154000, Errors: 0, Skipped: 0
# Processed 155000 rows. Inserted: 155000, Errors: 0, Skipped: 0
# Processed 156000 rows. Inserted: 156000, Errors: 0, Skipped: 0
# Processed 157000 rows. Inserted: 157000, Errors: 0, Skipped: 0
# Processed 158000 rows. Inserted: 158000, Errors: 0, Skipped: 0
# Processed 159000 rows. Inserted: 159000, Errors: 0, Skipped: 0
# Processed 160000 rows. Inserted: 160000, Errors: 0, Skipped: 0
# Processed 161000 rows. Inserted: 161000, Errors: 0, Skipped: 0
# Processed 162000 rows. Inserted: 162000, Errors: 0, Skipped: 0
# Processed 163000 rows. Inserted: 163000, Errors: 0, Skipped: 0
# Processed 164000 rows. Inserted: 164000, Errors: 0, Skipped: 0
# Processed 165000 rows. Inserted: 165000, Errors: 0, Skipped: 0
# Processed 166000 rows. Inserted: 166000, Errors: 0, Skipped: 0
# Processed 167000 rows. Inserted: 167000, Errors: 0, Skipped: 0
# Processed 168000 rows. Inserted: 168000, Errors: 0, Skipped: 0
# Processed 169000 rows. Inserted: 169000, Errors: 0, Skipped: 0
# Processed 170000 rows. Inserted: 170000, Errors: 0, Skipped: 0
# Processed 171000 rows. Inserted: 171000, Errors: 0, Skipped: 0
# Processed 172000 rows. Inserted: 172000, Errors: 0, Skipped: 0
# Processed 173000 rows. Inserted: 173000, Errors: 0, Skipped: 0
# Processed 174000 rows. Inserted: 174000, Errors: 0, Skipped: 0
# Processed 175000 rows. Inserted: 175000, Errors: 0, Skipped: 0
# Processed 176000 rows. Inserted: 176000, Errors: 0, Skipped: 0
# Processed 177000 rows. Inserted: 177000, Errors: 0, Skipped: 0
# Processed 178000 rows. Inserted: 178000, Errors: 0, Skipped: 0
# Processed 179000 rows. Inserted: 179000, Errors: 0, Skipped: 0
# Processed 180000 rows. Inserted: 180000, Errors: 0, Skipped: 0
# Processed 181000 rows. Inserted: 181000, Errors: 0, Skipped: 0
# Processed 182000 rows. Inserted: 182000, Errors: 0, Skipped: 0
# Processed 183000 rows. Inserted: 183000, Errors: 0, Skipped: 0
# Processed 184000 rows. Inserted: 184000, Errors: 0, Skipped: 0
# Processed 185000 rows. Inserted: 185000, Errors: 0, Skipped: 0
# Processed 186000 rows. Inserted: 186000, Errors: 0, Skipped: 0
# Processed 187000 rows. Inserted: 187000, Errors: 0, Skipped: 0
# Processed 188000 rows. Inserted: 188000, Errors: 0, Skipped: 0
# Processed 189000 rows. Inserted: 189000, Errors: 0, Skipped: 0
# Processed 190000 rows. Inserted: 190000, Errors: 0, Skipped: 0
# Processed 191000 rows. Inserted: 191000, Errors: 0, Skipped: 0
# Processed 192000 rows. Inserted: 192000, Errors: 0, Skipped: 0
# Processed 193000 rows. Inserted: 193000, Errors: 0, Skipped: 0
# Processed 194000 rows. Inserted: 194000, Errors: 0, Skipped: 0
# Processed 195000 rows. Inserted: 195000, Errors: 0, Skipped: 0
# Processed 196000 rows. Inserted: 196000, Errors: 0, Skipped: 0
# Processed 197000 rows. Inserted: 197000, Errors: 0, Skipped: 0
# Processed 198000 rows. Inserted: 198000, Errors: 0, Skipped: 0
# Processed 199000 rows. Inserted: 199000, Errors: 0, Skipped: 0
# Processed 200000 rows. Inserted: 200000, Errors: 0, Skipped: 0
# Processed 201000 rows. Inserted: 201000, Errors: 0, Skipped: 0
# Processed 202000 rows. Inserted: 202000, Errors: 0, Skipped: 0
# Processed 203000 rows. Inserted: 203000, Errors: 0, Skipped: 0
# Processed 204000 rows. Inserted: 204000, Errors: 0, Skipped: 0
# Processed 205000 rows. Inserted: 205000, Errors: 0, Skipped: 0
# Processed 206000 rows. Inserted: 206000, Errors: 0, Skipped: 0
# Processed 207000 rows. Inserted: 207000, Errors: 0, Skipped: 0
# Processed 208000 rows. Inserted: 208000, Errors: 0, Skipped: 0
# Processed 209000 rows. Inserted: 209000, Errors: 0, Skipped: 0
# Processed 210000 rows. Inserted: 210000, Errors: 0, Skipped: 0
# Processed 211000 rows. Inserted: 211000, Errors: 0, Skipped: 0
# Processed 212000 rows. Inserted: 212000, Errors: 0, Skipped: 0
# Processed 213000 rows. Inserted: 213000, Errors: 0, Skipped: 0
# Processed 214000 rows. Inserted: 214000, Errors: 0, Skipped: 0
# Processed 215000 rows. Inserted: 215000, Errors: 0, Skipped: 0
# Processed 216000 rows. Inserted: 216000, Errors: 0, Skipped: 0
# Processed 217000 rows. Inserted: 217000, Errors: 0, Skipped: 0
# Processed 218000 rows. Inserted: 218000, Errors: 0, Skipped: 0
# Processed 219000 rows. Inserted: 219000, Errors: 0, Skipped: 0
# Processed 220000 rows. Inserted: 220000, Errors: 0, Skipped: 0
# Processed 221000 rows. Inserted: 221000, Errors: 0, Skipped: 0
# Processed 222000 rows. Inserted: 222000, Errors: 0, Skipped: 0
# Processed 223000 rows. Inserted: 223000, Errors: 0, Skipped: 0
# Processed 224000 rows. Inserted: 224000, Errors: 0, Skipped: 0
# Processed 225000 rows. Inserted: 225000, Errors: 0, Skipped: 0
# Processed 226000 rows. Inserted: 226000, Errors: 0, Skipped: 0
# Processed 227000 rows. Inserted: 227000, Errors: 0, Skipped: 0
# Processed 228000 rows. Inserted: 228000, Errors: 0, Skipped: 0
# Processed 229000 rows. Inserted: 229000, Errors: 0, Skipped: 0
# Processed 230000 rows. Inserted: 230000, Errors: 0, Skipped: 0
# Processed 231000 rows. Inserted: 231000, Errors: 0, Skipped: 0
# Processed 232000 rows. Inserted: 232000, Errors: 0, Skipped: 0
# Processed 233000 rows. Inserted: 233000, Errors: 0, Skipped: 0
# Processed 234000 rows. Inserted: 234000, Errors: 0, Skipped: 0
# Processed 235000 rows. Inserted: 235000, Errors: 0, Skipped: 0
# Processed 236000 rows. Inserted: 236000, Errors: 0, Skipped: 0
# Processed 237000 rows. Inserted: 237000, Errors: 0, Skipped: 0
# Processed 238000 rows. Inserted: 238000, Errors: 0, Skipped: 0
# Processed 239000 rows. Inserted: 239000, Errors: 0, Skipped: 0
# Processed 240000 rows. Inserted: 240000, Errors: 0, Skipped: 0
# Processed 241000 rows. Inserted: 241000, Errors: 0, Skipped: 0
# Processed 242000 rows. Inserted: 242000, Errors: 0, Skipped: 0
# Processed 243000 rows. Inserted: 243000, Errors: 0, Skipped: 0
# Processed 244000 rows. Inserted: 244000, Errors: 0, Skipped: 0
# Processed 245000 rows. Inserted: 245000, Errors: 0, Skipped: 0
# Processed 246000 rows. Inserted: 246000, Errors: 0, Skipped: 0
# Processed 247000 rows. Inserted: 247000, Errors: 0, Skipped: 0
# Processed 248000 rows. Inserted: 248000, Errors: 0, Skipped: 0
# Processed 249000 rows. Inserted: 249000, Errors: 0, Skipped: 0
# Processed 250000 rows. Inserted: 250000, Errors: 0, Skipped: 0
# Processed 251000 rows. Inserted: 251000, Errors: 0, Skipped: 0
# Processed 252000 rows. Inserted: 252000, Errors: 0, Skipped: 0
# Processed 253000 rows. Inserted: 253000, Errors: 0, Skipped: 0
# Processed 254000 rows. Inserted: 254000, Errors: 0, Skipped: 0
# Processed 255000 rows. Inserted: 255000, Errors: 0, Skipped: 0
# Processed 256000 rows. Inserted: 256000, Errors: 0, Skipped: 0
# Processed 257000 rows. Inserted: 257000, Errors: 0, Skipped: 0
# Processed 258000 rows. Inserted: 258000, Errors: 0, Skipped: 0
# Processed 259000 rows. Inserted: 259000, Errors: 0, Skipped: 0
# Processed 260000 rows. Inserted: 260000, Errors: 0, Skipped: 0
# Processed 261000 rows. Inserted: 261000, Errors: 0, Skipped: 0
# Processed 262000 rows. Inserted: 262000, Errors: 0, Skipped: 0
# Processed 263000 rows. Inserted: 263000, Errors: 0, Skipped: 0
# Processed 264000 rows. Inserted: 264000, Errors: 0, Skipped: 0
# Processed 265000 rows. Inserted: 265000, Errors: 0, Skipped: 0
# Processed 266000 rows. Inserted: 266000, Errors: 0, Skipped: 0
# Processed 267000 rows. Inserted: 267000, Errors: 0, Skipped: 0
# Processed 268000 rows. Inserted: 268000, Errors: 0, Skipped: 0
# Processed 269000 rows. Inserted: 269000, Errors: 0, Skipped: 0
# Processed 270000 rows. Inserted: 270000, Errors: 0, Skipped: 0
# Processed 271000 rows. Inserted: 271000, Errors: 0, Skipped: 0
# Processed 272000 rows. Inserted: 272000, Errors: 0, Skipped: 0
# Processed 273000 rows. Inserted: 273000, Errors: 0, Skipped: 0
# Processed 274000 rows. Inserted: 274000, Errors: 0, Skipped: 0
# Processed 275000 rows. Inserted: 275000, Errors: 0, Skipped: 0
# Processed 276000 rows. Inserted: 276000, Errors: 0, Skipped: 0
# Processed 277000 rows. Inserted: 277000, Errors: 0, Skipped: 0
# Processed 278000 rows. Inserted: 278000, Errors: 0, Skipped: 0
# Processed 279000 rows. Inserted: 279000, Errors: 0, Skipped: 0
# Processed 280000 rows. Inserted: 280000, Errors: 0, Skipped: 0
# Processed 281000 rows. Inserted: 281000, Errors: 0, Skipped: 0
# Processed 282000 rows. Inserted: 282000, Errors: 0, Skipped: 0
# Processed 283000 rows. Inserted: 283000, Errors: 0, Skipped: 0
# Processed 284000 rows. Inserted: 284000, Errors: 0, Skipped: 0
# Processed 285000 rows. Inserted: 285000, Errors: 0, Skipped: 0
# Processed 286000 rows. Inserted: 286000, Errors: 0, Skipped: 0
# Processed 287000 rows. Inserted: 287000, Errors: 0, Skipped: 0
# Processed 288000 rows. Inserted: 288000, Errors: 0, Skipped: 0
# Processed 289000 rows. Inserted: 289000, Errors: 0, Skipped: 0
# Processed 290000 rows. Inserted: 290000, Errors: 0, Skipped: 0
# Processed 291000 rows. Inserted: 291000, Errors: 0, Skipped: 0
# Processed 292000 rows. Inserted: 292000, Errors: 0, Skipped: 0
# Processed 293000 rows. Inserted: 293000, Errors: 0, Skipped: 0
# Processed 294000 rows. Inserted: 294000, Errors: 0, Skipped: 0
# Processed 295000 rows. Inserted: 295000, Errors: 0, Skipped: 0
# Processed 296000 rows. Inserted: 296000, Errors: 0, Skipped: 0
# Processed 297000 rows. Inserted: 297000, Errors: 0, Skipped: 0
# Processed 298000 rows. Inserted: 298000, Errors: 0, Skipped: 0
# Processed 299000 rows. Inserted: 299000, Errors: 0, Skipped: 0
# Processed 300000 rows. Inserted: 300000, Errors: 0, Skipped: 0
# Processed 301000 rows. Inserted: 301000, Errors: 0, Skipped: 0
# Processed 302000 rows. Inserted: 302000, Errors: 0, Skipped: 0
# Processed 303000 rows. Inserted: 303000, Errors: 0, Skipped: 0
# Processed 304000 rows. Inserted: 304000, Errors: 0, Skipped: 0
# Processed 305000 rows. Inserted: 305000, Errors: 0, Skipped: 0
# Processed 306000 rows. Inserted: 306000, Errors: 0, Skipped: 0
# Processed 307000 rows. Inserted: 307000, Errors: 0, Skipped: 0
# Processed 308000 rows. Inserted: 308000, Errors: 0, Skipped: 0
# Processed 309000 rows. Inserted: 309000, Errors: 0, Skipped: 0
# Processed 310000 rows. Inserted: 310000, Errors: 0, Skipped: 0
# Processed 311000 rows. Inserted: 311000, Errors: 0, Skipped: 0
# Processed 312000 rows. Inserted: 312000, Errors: 0, Skipped: 0
# Processed 313000 rows. Inserted: 313000, Errors: 0, Skipped: 0
# Processed 314000 rows. Inserted: 314000, Errors: 0, Skipped: 0
# Processed 315000 rows. Inserted: 315000, Errors: 0, Skipped: 0
# Processed 316000 rows. Inserted: 316000, Errors: 0, Skipped: 0
# Processed 317000 rows. Inserted: 317000, Errors: 0, Skipped: 0
# Processed 318000 rows. Inserted: 318000, Errors: 0, Skipped: 0
# Processed 319000 rows. Inserted: 319000, Errors: 0, Skipped: 0
# Processed 320000 rows. Inserted: 320000, Errors: 0, Skipped: 0
# Processed 321000 rows. Inserted: 321000, Errors: 0, Skipped: 0
# Processed 322000 rows. Inserted: 322000, Errors: 0, Skipped: 0
# Processed 323000 rows. Inserted: 323000, Errors: 0, Skipped: 0
# Processed 324000 rows. Inserted: 324000, Errors: 0, Skipped: 0
# Processed 325000 rows. Inserted: 325000, Errors: 0, Skipped: 0
# Processed 326000 rows. Inserted: 326000, Errors: 0, Skipped: 0
# Processed 327000 rows. Inserted: 327000, Errors: 0, Skipped: 0
# Processed 328000 rows. Inserted: 328000, Errors: 0, Skipped: 0
# Processed 329000 rows. Inserted: 329000, Errors: 0, Skipped: 0
# Processed 330000 rows. Inserted: 330000, Errors: 0, Skipped: 0
# Processed 331000 rows. Inserted: 331000, Errors: 0, Skipped: 0
# Processed 332000 rows. Inserted: 332000, Errors: 0, Skipped: 0
# Processed 333000 rows. Inserted: 333000, Errors: 0, Skipped: 0
# Processed 334000 rows. Inserted: 334000, Errors: 0, Skipped: 0
# Processed 335000 rows. Inserted: 335000, Errors: 0, Skipped: 0
# Processed 336000 rows. Inserted: 336000, Errors: 0, Skipped: 0
# Processed 337000 rows. Inserted: 337000, Errors: 0, Skipped: 0
# Processed 338000 rows. Inserted: 338000, Errors: 0, Skipped: 0
# Processed 339000 rows. Inserted: 339000, Errors: 0, Skipped: 0
# Processed 340000 rows. Inserted: 340000, Errors: 0, Skipped: 0
# Processed 341000 rows. Inserted: 341000, Errors: 0, Skipped: 0
# Processed 342000 rows. Inserted: 342000, Errors: 0, Skipped: 0
# Processed 343000 rows. Inserted: 343000, Errors: 0, Skipped: 0
# Processed 344000 rows. Inserted: 344000, Errors: 0, Skipped: 0
# Processed 345000 rows. Inserted: 345000, Errors: 0, Skipped: 0
# Processed 346000 rows. Inserted: 346000, Errors: 0, Skipped: 0
# Processed 347000 rows. Inserted: 347000, Errors: 0, Skipped: 0
# Processed 348000 rows. Inserted: 348000, Errors: 0, Skipped: 0
# Processed 349000 rows. Inserted: 349000, Errors: 0, Skipped: 0
# Processed 350000 rows. Inserted: 350000, Errors: 0, Skipped: 0
# Processed 351000 rows. Inserted: 351000, Errors: 0, Skipped: 0
# Processed 352000 rows. Inserted: 352000, Errors: 0, Skipped: 0
# Processed 353000 rows. Inserted: 353000, Errors: 0, Skipped: 0
# Processed 354000 rows. Inserted: 354000, Errors: 0, Skipped: 0
# Processed 355000 rows. Inserted: 355000, Errors: 0, Skipped: 0
# Processed 356000 rows. Inserted: 356000, Errors: 0, Skipped: 0
# Processed 357000 rows. Inserted: 357000, Errors: 0, Skipped: 0
# Processed 358000 rows. Inserted: 358000, Errors: 0, Skipped: 0
# Processed 359000 rows. Inserted: 359000, Errors: 0, Skipped: 0
# Processed 360000 rows. Inserted: 360000, Errors: 0, Skipped: 0
# Processed 361000 rows. Inserted: 361000, Errors: 0, Skipped: 0
# Processed 362000 rows. Inserted: 362000, Errors: 0, Skipped: 0
# Processed 363000 rows. Inserted: 363000, Errors: 0, Skipped: 0
# Processed 364000 rows. Inserted: 364000, Errors: 0, Skipped: 0
# Processed 365000 rows. Inserted: 365000, Errors: 0, Skipped: 0
# Processed 366000 rows. Inserted: 366000, Errors: 0, Skipped: 0
# Processed 367000 rows. Inserted: 367000, Errors: 0, Skipped: 0
# Processed 368000 rows. Inserted: 368000, Errors: 0, Skipped: 0
# Processed 369000 rows. Inserted: 369000, Errors: 0, Skipped: 0
# Processed 370000 rows. Inserted: 370000, Errors: 0, Skipped: 0
# Processed 371000 rows. Inserted: 371000, Errors: 0, Skipped: 0
# Processed 372000 rows. Inserted: 372000, Errors: 0, Skipped: 0
# Processed 373000 rows. Inserted: 373000, Errors: 0, Skipped: 0
# Processed 374000 rows. Inserted: 374000, Errors: 0, Skipped: 0
# Processed 375000 rows. Inserted: 375000, Errors: 0, Skipped: 0
# Processed 376000 rows. Inserted: 376000, Errors: 0, Skipped: 0
# Processed 377000 rows. Inserted: 377000, Errors: 0, Skipped: 0
# Processed 378000 rows. Inserted: 378000, Errors: 0, Skipped: 0
# Processed 379000 rows. Inserted: 379000, Errors: 0, Skipped: 0
# Processed 380000 rows. Inserted: 380000, Errors: 0, Skipped: 0
# Processed 381000 rows. Inserted: 381000, Errors: 0, Skipped: 0
# Processed 382000 rows. Inserted: 382000, Errors: 0, Skipped: 0
# Processed 383000 rows. Inserted: 383000, Errors: 0, Skipped: 0
# Processed 384000 rows. Inserted: 384000, Errors: 0, Skipped: 0
# Processed 385000 rows. Inserted: 385000, Errors: 0, Skipped: 0
# Processed 386000 rows. Inserted: 386000, Errors: 0, Skipped: 0
# Processed 387000 rows. Inserted: 387000, Errors: 0, Skipped: 0
# Processed 388000 rows. Inserted: 388000, Errors: 0, Skipped: 0
# Processed 389000 rows. Inserted: 389000, Errors: 0, Skipped: 0
# Processed 390000 rows. Inserted: 390000, Errors: 0, Skipped: 0
# Processed 391000 rows. Inserted: 391000, Errors: 0, Skipped: 0
# Processed 392000 rows. Inserted: 392000, Errors: 0, Skipped: 0
# Processed 393000 rows. Inserted: 393000, Errors: 0, Skipped: 0
# Processed 394000 rows. Inserted: 394000, Errors: 0, Skipped: 0
# Processed 395000 rows. Inserted: 395000, Errors: 0, Skipped: 0
# Processed 396000 rows. Inserted: 396000, Errors: 0, Skipped: 0
# Processed 397000 rows. Inserted: 397000, Errors: 0, Skipped: 0
# Processed 398000 rows. Inserted: 398000, Errors: 0, Skipped: 0
# Processed 399000 rows. Inserted: 399000, Errors: 0, Skipped: 0
# Processed 400000 rows. Inserted: 400000, Errors: 0, Skipped: 0
# Processed 401000 rows. Inserted: 401000, Errors: 0, Skipped: 0
# Processed 402000 rows. Inserted: 402000, Errors: 0, Skipped: 0
# Processed 403000 rows. Inserted: 403000, Errors: 0, Skipped: 0
# Processed 404000 rows. Inserted: 404000, Errors: 0, Skipped: 0
# Processed 405000 rows. Inserted: 405000, Errors: 0, Skipped: 0
# Processed 406000 rows. Inserted: 406000, Errors: 0, Skipped: 0
# Processed 407000 rows. Inserted: 407000, Errors: 0, Skipped: 0
# Processed 408000 rows. Inserted: 408000, Errors: 0, Skipped: 0
# Processed 409000 rows. Inserted: 409000, Errors: 0, Skipped: 0
# Processed 410000 rows. Inserted: 410000, Errors: 0, Skipped: 0
# Processed 411000 rows. Inserted: 411000, Errors: 0, Skipped: 0
# Processed 412000 rows. Inserted: 412000, Errors: 0, Skipped: 0
# Processed 413000 rows. Inserted: 413000, Errors: 0, Skipped: 0
# Processed 414000 rows. Inserted: 414000, Errors: 0, Skipped: 0
# Processed 415000 rows. Inserted: 415000, Errors: 0, Skipped: 0
# Processed 416000 rows. Inserted: 416000, Errors: 0, Skipped: 0
# Processed 417000 rows. Inserted: 417000, Errors: 0, Skipped: 0
# Processed 418000 rows. Inserted: 418000, Errors: 0, Skipped: 0
# Processed 419000 rows. Inserted: 419000, Errors: 0, Skipped: 0
# Processed 420000 rows. Inserted: 420000, Errors: 0, Skipped: 0
# Processed 421000 rows. Inserted: 421000, Errors: 0, Skipped: 0
# Processed 422000 rows. Inserted: 422000, Errors: 0, Skipped: 0
# Processed 423000 rows. Inserted: 423000, Errors: 0, Skipped: 0
# Processed 424000 rows. Inserted: 424000, Errors: 0, Skipped: 0
# Processed 425000 rows. Inserted: 425000, Errors: 0, Skipped: 0
# Processed 426000 rows. Inserted: 426000, Errors: 0, Skipped: 0
# Processed 427000 rows. Inserted: 427000, Errors: 0, Skipped: 0
# Processed 428000 rows. Inserted: 428000, Errors: 0, Skipped: 0
# Processed 429000 rows. Inserted: 429000, Errors: 0, Skipped: 0
# Processed 430000 rows. Inserted: 430000, Errors: 0, Skipped: 0
# Processed 431000 rows. Inserted: 431000, Errors: 0, Skipped: 0
# Processed 432000 rows. Inserted: 432000, Errors: 0, Skipped: 0
# Processed 433000 rows. Inserted: 433000, Errors: 0, Skipped: 0
# Processed 434000 rows. Inserted: 434000, Errors: 0, Skipped: 0
# Processed 435000 rows. Inserted: 435000, Errors: 0, Skipped: 0
# Processed 436000 rows. Inserted: 436000, Errors: 0, Skipped: 0
# Processed 437000 rows. Inserted: 437000, Errors: 0, Skipped: 0
# Processed 438000 rows. Inserted: 438000, Errors: 0, Skipped: 0
# Processed 439000 rows. Inserted: 439000, Errors: 0, Skipped: 0
# Processed 440000 rows. Inserted: 440000, Errors: 0, Skipped: 0
# Processed 441000 rows. Inserted: 441000, Errors: 0, Skipped: 0
# Processed 442000 rows. Inserted: 442000, Errors: 0, Skipped: 0
# Processed 443000 rows. Inserted: 443000, Errors: 0, Skipped: 0
# Processed 444000 rows. Inserted: 444000, Errors: 0, Skipped: 0
# Processed 445000 rows. Inserted: 445000, Errors: 0, Skipped: 0
# Processed 446000 rows. Inserted: 446000, Errors: 0, Skipped: 0
# Processed 447000 rows. Inserted: 447000, Errors: 0, Skipped: 0
# Processed 448000 rows. Inserted: 448000, Errors: 0, Skipped: 0
# Processed 449000 rows. Inserted: 449000, Errors: 0, Skipped: 0
# Processed 450000 rows. Inserted: 450000, Errors: 0, Skipped: 0
# Processed 451000 rows. Inserted: 451000, Errors: 0, Skipped: 0
# Processed 452000 rows. Inserted: 452000, Errors: 0, Skipped: 0
# Processed 453000 rows. Inserted: 453000, Errors: 0, Skipped: 0
# Processed 454000 rows. Inserted: 454000, Errors: 0, Skipped: 0
# Processed 455000 rows. Inserted: 455000, Errors: 0, Skipped: 0
# Processed 456000 rows. Inserted: 456000, Errors: 0, Skipped: 0
# Processed 457000 rows. Inserted: 457000, Errors: 0, Skipped: 0
# Processed 458000 rows. Inserted: 458000, Errors: 0, Skipped: 0
# Processed 459000 rows. Inserted: 459000, Errors: 0, Skipped: 0
# Processed 460000 rows. Inserted: 460000, Errors: 0, Skipped: 0
# Processed 461000 rows. Inserted: 461000, Errors: 0, Skipped: 0
# Processed 462000 rows. Inserted: 462000, Errors: 0, Skipped: 0
# Processed 463000 rows. Inserted: 463000, Errors: 0, Skipped: 0
# Processed 464000 rows. Inserted: 464000, Errors: 0, Skipped: 0
# Processed 465000 rows. Inserted: 465000, Errors: 0, Skipped: 0
# Processed 466000 rows. Inserted: 466000, Errors: 0, Skipped: 0
# Processed 467000 rows. Inserted: 467000, Errors: 0, Skipped: 0
# Processed 468000 rows. Inserted: 468000, Errors: 0, Skipped: 0
# Processed 469000 rows. Inserted: 469000, Errors: 0, Skipped: 0
# Processed 470000 rows. Inserted: 470000, Errors: 0, Skipped: 0
# Processed 471000 rows. Inserted: 471000, Errors: 0, Skipped: 0
# Processed 472000 rows. Inserted: 472000, Errors: 0, Skipped: 0
# Processed 473000 rows. Inserted: 473000, Errors: 0, Skipped: 0
# Processed 474000 rows. Inserted: 474000, Errors: 0, Skipped: 0
# Processed 475000 rows. Inserted: 475000, Errors: 0, Skipped: 0
# Processed 476000 rows. Inserted: 476000, Errors: 0, Skipped: 0
# Processed 477000 rows. Inserted: 477000, Errors: 0, Skipped: 0
# Processed 478000 rows. Inserted: 478000, Errors: 0, Skipped: 0
# Processed 479000 rows. Inserted: 479000, Errors: 0, Skipped: 0
# Processed 480000 rows. Inserted: 480000, Errors: 0, Skipped: 0
# Processed 481000 rows. Inserted: 481000, Errors: 0, Skipped: 0
# Processed 482000 rows. Inserted: 482000, Errors: 0, Skipped: 0
# Processed 483000 rows. Inserted: 483000, Errors: 0, Skipped: 0
# Processed 484000 rows. Inserted: 484000, Errors: 0, Skipped: 0
# Processed 485000 rows. Inserted: 485000, Errors: 0, Skipped: 0
# Processed 486000 rows. Inserted: 486000, Errors: 0, Skipped: 0
# Processed 487000 rows. Inserted: 487000, Errors: 0, Skipped: 0
# Processed 488000 rows. Inserted: 488000, Errors: 0, Skipped: 0
# Processed 489000 rows. Inserted: 489000, Errors: 0, Skipped: 0
# Processed 490000 rows. Inserted: 490000, Errors: 0, Skipped: 0
# Processed 491000 rows. Inserted: 491000, Errors: 0, Skipped: 0
# Processed 492000 rows. Inserted: 492000, Errors: 0, Skipped: 0
# Processed 493000 rows. Inserted: 493000, Errors: 0, Skipped: 0
# Processed 494000 rows. Inserted: 494000, Errors: 0, Skipped: 0
# Processed 495000 rows. Inserted: 495000, Errors: 0, Skipped: 0
# Processed 496000 rows. Inserted: 496000, Errors: 0, Skipped: 0
# Processed 497000 rows. Inserted: 497000, Errors: 0, Skipped: 0
# Processed 498000 rows. Inserted: 498000, Errors: 0, Skipped: 0
# Processed 499000 rows. Inserted: 499000, Errors: 0, Skipped: 0
# Processed 500000 rows. Inserted: 500000, Errors: 0, Skipped: 0
#
# Data insertion summary for the first 500000 rows:
# Successfully inserted rows: 500000
# Rows with errors during put: 0
# Rows skipped (missing key components or no data): 0

# %% [markdown]
# # Part 2: Retrieve data from HBase and Analyze in Python

# %% [markdown]
# ## Connection to HBase:

# %%
# HBase connection details (same as before)
HBASE_HOST = 'localhost'
HBASE_PORT = 9090 # Default Thrift server port
NAMESPACE = 'practice'
TABLE_NAME = 'crimes'
FULL_TABLE_NAME = f'{NAMESPACE}:{TABLE_NAME}'

# Column families
CF_LOC = 'cf_loc'
CF_CRIME = 'cf_crime'
CF_VICTIM = 'cf_victim'

def connect_to_hbase():
    try:
        connection = happybase.Connection(
            host=HBASE_HOST,
            port=HBASE_PORT,
            timeout=60000, # Increased timeout
            autoconnect=True
        )
        print(f"Successfully connected to HBase at {HBASE_HOST}:{HBASE_PORT}!")
        return connection
    except Exception as e:
        print(f"Error connecting to HBase: {e}")
        return None

connection = connect_to_hbase()
# Out:
# Successfully connected to HBase at localhost:9090!

# %% [markdown]
# ## Helper Function to Decode HBase Data:

# %%
def decode_hbase_row(row_data):
    """Decodes a row from HBase (keys and values) from bytes to strings."""
    decoded_row = {}
    for key, value in row_data.items():
        decoded_row[key.decode('utf-8')] = value.decode('utf-8')
    return decoded_row

# %% [markdown]
# ## Retrieve Data for Specific Queries:

# %% [markdown]
# ### A. All SHOPLIFTING and VANDALISM crimes (if the label of the crime contains it)

# %%
def get_shoplifting_vandalism_crimes(conn, table_name_str, limit=100):
    if not conn:
        print("No HBase connection.")
        return []

    results = []
    try:
        table = conn.table(table_name_str)
        
        # Filter: cf_crime:crm_cd_desc CONTAINS 'SHOPLIFTING' OR cf_crime:crm_cd_desc CONTAINS 'VANDALISM'
        # Using SingleColumnValueFilter with SubstringComparator
        # FilterList with MUST_PASS_ONE for OR condition
        shoplifting_filter = "SingleColumnValueFilter ('cf_crime', 'crm_cd_desc', =, 'substring:SHOPLIFTING')"
        vandalism_filter = "SingleColumnValueFilter ('cf_crime', 'crm_cd_desc', =, 'substring:VANDALISM')"
        
        # Constructing a FilterList for OR is more complex with HappyBase's string filters.
        # Often, for complex ORs, it's easier to do two separate scans or fetch more data and filter in Python.
        # However, let's try to make a more complex filter string if possible, or do two scans.

        # Option 1: Two separate scans and merge (simpler to implement correctly)
        scan_filter_shoplifting = shoplifting_filter
        print(f"Scanning for SHOPLIFTING with filter: {scan_filter_shoplifting}")
        for key, data in table.scan(filter=scan_filter_shoplifting, limit=limit//2 if limit else None): # limit per scan
            decoded_data = decode_hbase_row(data)
            decoded_data['row_key'] = key.decode('utf-8')
            results.append(decoded_data)
        
        scan_filter_vandalism = vandalism_filter
        print(f"Scanning for VANDALISM with filter: {scan_filter_vandalism}")
        for key, data in table.scan(filter=scan_filter_vandalism, limit=limit//2 if limit else None): # limit per scan
            decoded_data = decode_hbase_row(data)
            decoded_data['row_key'] = key.decode('utf-8')
            # Avoid duplicates if a crime could be both (unlikely for crm_cd_desc)
            # This basic append might have duplicates if a row matches both, but for different crime types it's fine.
            results.append(decoded_data)

        # If you need a strict limit on the total unique results, you'd manage a set of row keys.
        print(f"Found {len(results)} SHOPLIFTING/VANDALISM crimes (up to combined limit).")

    except Exception as e:
        print(f"Error retrieving SHOPLIFTING/VANDALISM crimes: {e}")
    return results

if connection:
    shoplifting_vandalism_results = get_shoplifting_vandalism_crimes(connection, FULL_TABLE_NAME, limit=20) # Get up to 20
    print("\n--- Shoplifting/Vandalism Results (Sample) ---")
    for res in shoplifting_vandalism_results[:5]: # Print first 5
        print(res)
    # Convert to DataFrame for easier viewing/comparison
    df_shop_vand = pd.DataFrame(shoplifting_vandalism_results)
    print("\nDataFrame from Shoplifting/Vandalism HBase results:")
    display(df_shop_vand.head())
# Out:
# Scanning for SHOPLIFTING with filter: SingleColumnValueFilter ('cf_crime', 'crm_cd_desc', =, 'substring:SHOPLIFTING')
# Scanning for VANDALISM with filter: SingleColumnValueFilter ('cf_crime', 'crm_cd_desc', =, 'substring:VANDALISM')
# Found 20 SHOPLIFTING/VANDALISM crimes (up to combined limit).
#
# --- Shoplifting/Vandalism Results (Sample) ---
# {'cf_crime:crm_cd': '442', 'cf_crime:crm_cd_1': '442.0', 'cf_crime:crm_cd_desc': 'SHOPLIFTING - PETTY THEFT ($950 & UNDER)', 'cf_crime:date_occ': '01/09/2020 12:00:00 AM', 'cf_crime:date_rptd': '01/09/2020 12:00:00 AM', 'cf_crime:mocodes': '0104 0325 0202 0216 0346', 'cf_crime:part_1_2_val': '1', 'cf_crime:status': 'IC', 'cf_crime:status_desc': 'Invest Cont', 'cf_crime:time_occ': '1825', 'cf_loc:area_name': 'Southwest', 'cf_loc:lat': '34.0052', 'cf_loc:location': '4300 S  WESTERN                      AV', 'cf_loc:lon': '-118.3089', 'cf_loc:premis_cd': '248.0', 'cf_loc:premis_desc': 'CELL PHONE STORE', 'cf_loc:rpt_dist_no': '395', 'cf_victim:vict_age': '19', 'cf_victim:vict_descent': 'X', 'cf_victim:vict_sex': 'X', 'row_key': '00_2020_01_03_200304500'}
# {'cf_crime:crm_cd': '442', 'cf_crime:crm_cd_1': '442.0', 'cf_crime:crm_cd_desc': 'SHOPLIFTING - PETTY THEFT ($950 & UNDER)', 'cf_crime:date_occ': '01/15/2020 12:00:00 AM', 'cf_crime:date_rptd': '01/15/2020 12:00:00 AM', 'cf_crime:mocodes': '0104 0325', 'cf_crime:part_1_2_val': '1', 'cf_crime:status': 'AO', 'cf_crime:status_desc': 'Adult Other', 'cf_crime:time_occ': '2140', 'cf_loc:area_name': 'Southwest', 'cf_loc:lat': '34.0255', 'cf_loc:location': '5100 W  JEFFERSON                    BL', 'cf_loc:lon': '-118.3548', 'cf_loc:premis_cd': '301.0', 'cf_loc:premis_desc': 'GAS STATION', 'cf_loc:rpt_dist_no': '312', 'cf_victim:vict_age': '0', 'cf_victim:vict_descent': 'X', 'cf_victim:vict_sex': 'X', 'row_key': '00_2020_01_03_200304900'}
# {'cf_crime:crm_cd': '442', 'cf_crime:crm_cd_1': '442.0', 'cf_crime:crm_cd_desc': 'SHOPLIFTING - PETTY THEFT ($950 & UNDER)', 'cf_crime:date_occ': '01/24/2020 12:00:00 AM', 'cf_crime:date_rptd': '01/24/2020 12:00:00 AM', 'cf_crime:mocodes': '0325 1414', 'cf_crime:part_1_2_val': '1', 'cf_crime:status': 'IC', 'cf_crime:status_desc': 'Invest Cont', 'cf_crime:time_occ': '1840', 'cf_loc:area_name': 'Wilshire', 'cf_loc:lat': '34.073', 'cf_loc:location': '8400 W  3RD                          ST', 'cf_loc:lon': '-118.3731', 'cf_loc:premis_cd': '417.0', 'cf_loc:premis_desc': 'THE BEVERLY CONNECTION', 'cf_loc:rpt_dist_no': '722', 'cf_victim:vict_age': '0', 'cf_victim:vict_descent': 'W', 'cf_victim:vict_sex': 'M', 'row_key': '00_2020_01_07_200705100'}
# {'cf_crime:crm_cd': '343', 'cf_crime:crm_cd_1': '343.0', 'cf_crime:crm_cd_desc': 'SHOPLIFTING-GRAND THEFT ($950.01 & OVER)', 'cf_crime:date_occ': '01/04/2020 12:00:00 AM', 'cf_crime:date_rptd': '01/14/2020 12:00:00 AM', 'cf_crime:mocodes': '1414 0325 1822 2028 1420', 'cf_crime:part_1_2_val': '1', 'cf_crime:status': 'IC', 'cf_crime:status_desc': 'Invest Cont', 'cf_crime:time_occ': '1330', 'cf_loc:area_name': 'West LA', 'cf_loc:lat': '34.0605', 'cf_loc:location': '10200    SANTA MONICA                 BL', 'cf_loc:lon': '-118.4193', 'cf_loc:premis_cd': '203.0', 'cf_loc:premis_desc': 'OTHER BUSINESS', 'cf_loc:rpt_dist_no': '839', 'cf_victim:vict_age': '0', 'cf_victim:vict_descent': 'X', 'cf_victim:vict_sex': 'X', 'row_key': '00_2020_01_08_200804600'}
# {'cf_crime:crm_cd': '442', 'cf_crime:crm_cd_1': '442.0', 'cf_crime:crm_cd_desc': 'SHOPLIFTING - PETTY THEFT ($950 & UNDER)', 'cf_crime:date_occ': '01/22/2020 12:00:00 AM', 'cf_crime:date_rptd': '01/23/2020 12:00:00 AM', 'cf_crime:mocodes': '0325', 'cf_crime:part_1_2_val': '1', 'cf_crime:status': 'IC', 'cf_crime:status_desc': 'Invest Cont', 'cf_crime:time_occ': '2100', 'cf_loc:area_name': 'N Hollywood', 'cf_loc:lat': '34.1556', 'cf_loc:location': '11300    RIVERSIDE                    DR', 'cf_loc:lon': '-118.3771', 'cf_loc:premis_cd': '401.0', 'cf_loc:premis_desc': 'MINI-MART', 'cf_loc:rpt_dist_no': '1555', 'cf_victim:vict_age': '0', 'cf_victim:vict_descent': 'O', 'cf_victim:vict_sex': 'M', 'row_key': '00_2020_01_15_201505100'}
#
# DataFrame from Shoplifting/Vandalism HBase results:
#   cf_crime:crm_cd cf_crime:crm_cd_1                      cf_crime:crm_cd_desc  \
# 0             442             442.0  SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 1             442             442.0  SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 2             442             442.0  SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 3             343             343.0  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)
# 4             442             442.0  SHOPLIFTING - PETTY THEFT ($950 & UNDER)
#
#         cf_crime:date_occ      cf_crime:date_rptd          cf_crime:mocodes  \
# 0  01/09/2020 12:00:00 AM  01/09/2020 12:00:00 AM  0104 0325 0202 0216 0346
# 1  01/15/2020 12:00:00 AM  01/15/2020 12:00:00 AM                 0104 0325
# 2  01/24/2020 12:00:00 AM  01/24/2020 12:00:00 AM                 0325 1414
# 3  01/04/2020 12:00:00 AM  01/14/2020 12:00:00 AM  1414 0325 1822 2028 1420
# 4  01/22/2020 12:00:00 AM  01/23/2020 12:00:00 AM                      0325
#
#   cf_crime:part_1_2_val cf_crime:status cf_crime:status_desc  \
# 0                     1              IC          Invest Cont
# 1                     1              AO          Adult Other
# 2                     1              IC          Invest Cont
# 3                     1              IC          Invest Cont
# 4                     1              IC          Invest Cont
#
#   cf_crime:time_occ  ...      cf_loc:premis_desc cf_loc:rpt_dist_no  \
# 0              1825  ...        CELL PHONE STORE                395
# 1              2140  ...             GAS STATION                312
# 2              1840  ...  THE BEVERLY CONNECTION                722
# 3              1330  ...          OTHER BUSINESS                839
# 4              2100  ...               MINI-MART               1555
#
#   cf_victim:vict_age cf_victim:vict_descent cf_victim:vict_sex  \
# 0                 19                      X                  X
# 1                  0                      X                  X
# 2                  0                      W                  M
# 3                  0                      X                  X
# 4                  0                      O                  M
#
#                    row_key cf_crime:weapon_desc cf_crime:weapon_used_cd  \
# 0  00_2020_01_03_200304500                  NaN                     NaN
# 1  00_2020_01_03_200304900                  NaN                     NaN
# 2  00_2020_01_07_200705100                  NaN                     NaN
# 3  00_2020_01_08_200804600                  NaN                     NaN
# 4  00_2020_01_15_201505100                  NaN                     NaN
#
#   cf_loc:cross_street cf_crime:crm_cd_2
# 0                 NaN               NaN
# 1                 NaN               NaN
# 2                 NaN               NaN
# 3                 NaN               NaN
# 4                 NaN               NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ### B. Crimes occurring in Hollywood

# %%
def get_hollywood_crimes(conn, table_name_str, hollywood_areacode='06', hollywood_areaname='Hollywood', limit=100):
    if not conn:
        print("No HBase connection.")
        return []

    results = []
    try:
        table = conn.table(table_name_str)
        
        # Filter: Rowkey contains '_<hollywood_areacode>_' AND cf_loc:area_name IS 'Hollywood'
        # Regex for areacode in rowkey: ".*_AREACODE_.*" (e.g., ".*_06_.*")
        # This will scan ALL salts and ALL year/months for that area.
        # This can be a wide scan. For better performance, add year/month to rowkey filter if known.
        
        # Let's assume we want Hollywood crimes from 2020 as in Part 4
        year_to_filter = "2020"
        row_key_regex_filter = f".*_{year_to_filter}_.._{hollywood_areacode}_.*" # Any salt, specific year, any month, specific area

        filter_string = f"RowFilter (=, 'regexstring:{row_key_regex_filter}') AND SingleColumnValueFilter ('{CF_LOC}', 'area_name', =, 'binary:{hollywood_areaname}')"
        print(f"Scanning for Hollywood crimes with filter: {filter_string}")

        for key, data in table.scan(filter=filter_string, limit=limit):
            decoded_data = decode_hbase_row(data)
            decoded_data['row_key'] = key.decode('utf-8')
            results.append(decoded_data)
        print(f"Found {len(results)} crimes in {hollywood_areaname} (up to limit {limit}).")

    except Exception as e:
        print(f"Error retrieving {hollywood_areaname} crimes: {e}")
    return results

if connection:
    # VERIFY your Hollywood AREACODE and AREA NAME string
    hollywood_area_code_verified = '06' # Example, replace with your actual
    hollywood_area_name_verified = 'Hollywood' # Example, replace with your actual (check casing)
    
    hollywood_results = get_hollywood_crimes(connection, FULL_TABLE_NAME, 
                                             hollywood_areacode=hollywood_area_code_verified,
                                             hollywood_areaname=hollywood_area_name_verified, 
                                             limit=10)
    print(f"\n--- {hollywood_area_name_verified} Crime Results (Sample) ---")
    for res in hollywood_results[:5]:
        print(res)
    df_hollywood = pd.DataFrame(hollywood_results)
    print(f"\nDataFrame from {hollywood_area_name_verified} HBase results:")
    display(df_hollywood.head())
# Out:
# Scanning for Hollywood crimes with filter: RowFilter (=, 'regexstring:.*_2020_.._06_.*') AND SingleColumnValueFilter ('cf_loc', 'area_name', =, 'binary:Hollywood')
# Found 10 crimes in Hollywood (up to limit 10).
#
# --- Hollywood Crime Results (Sample) ---
# {'cf_crime:crm_cd': '510', 'cf_crime:crm_cd_1': '510.0', 'cf_crime:crm_cd_desc': 'VEHICLE - STOLEN', 'cf_crime:date_occ': '01/09/2020 12:00:00 AM', 'cf_crime:date_rptd': '01/10/2020 12:00:00 AM', 'cf_crime:part_1_2_val': '1', 'cf_crime:status': 'IC', 'cf_crime:status_desc': 'Invest Cont', 'cf_crime:time_occ': '1950', 'cf_loc:area_name': 'Hollywood', 'cf_loc:cross_street': 'ARGYLE                       BL', 'cf_loc:lat': '34.098', 'cf_loc:location': 'SUNSET', 'cf_loc:lon': '-118.3252', 'cf_loc:premis_cd': '101.0', 'cf_loc:premis_desc': 'STREET', 'cf_loc:rpt_dist_no': '647', 'cf_victim:vict_age': '0', 'row_key': '00_2020_01_06_200604400'}
# {'cf_crime:crm_cd': '510', 'cf_crime:crm_cd_1': '510.0', 'cf_crime:crm_cd_desc': 'VEHICLE - STOLEN', 'cf_crime:date_occ': '01/13/2020 12:00:00 AM', 'cf_crime:date_rptd': '01/14/2020 12:00:00 AM', 'cf_crime:part_1_2_val': '1', 'cf_crime:status': 'IC', 'cf_crime:status_desc': 'Invest Cont', 'cf_crime:time_occ': '1830', 'cf_loc:area_name': 'Hollywood', 'cf_loc:cross_street': 'BARTON                       AV', 'cf_loc:lat': '34.088', 'cf_loc:location': 'EL CENTRO                    AV', 'cf_loc:lon': '-118.3244', 'cf_loc:premis_cd': '101.0', 'cf_loc:premis_desc': 'STREET', 'cf_loc:rpt_dist_no': '656', 'cf_victim:vict_age': '0', 'row_key': '00_2020_01_06_200604600'}
# {'cf_crime:crm_cd': '330', 'cf_crime:crm_cd_1': '330.0', 'cf_crime:crm_cd_desc': 'BURGLARY FROM VEHICLE', 'cf_crime:date_occ': '01/15/2020 12:00:00 AM', 'cf_crime:date_rptd': '01/16/2020 12:00:00 AM', 'cf_crime:mocodes': '0344 0358 1300 1609', 'cf_crime:part_1_2_val': '1', 'cf_crime:status': 'IC', 'cf_crime:status_desc': 'Invest Cont', 'cf_crime:time_occ': '1', 'cf_loc:area_name': 'Hollywood', 'cf_loc:cross_street': 'SYCAMORE                     AV', 'cf_loc:lat': '34.1004', 'cf_loc:location': 'HAWTHORN                     AV', 'cf_loc:lon': '-118.3433', 'cf_loc:premis_cd': '101.0', 'cf_loc:premis_desc': 'STREET', 'cf_loc:rpt_dist_no': '645', 'cf_victim:vict_age': '35', 'cf_victim:vict_descent': 'O', 'cf_victim:vict_sex': 'M', 'row_key': '00_2020_01_06_200604700'}
# {'cf_crime:crm_cd': '745', 'cf_crime:crm_cd_1': '745.0', 'cf_crime:crm_cd_2': '998.0', 'cf_crime:crm_cd_desc': 'VANDALISM - MISDEAMEANOR ($399 OR UNDER)', 'cf_crime:date_occ': '01/18/2020 12:00:00 AM', 'cf_crime:date_rptd': '01/18/2020 12:00:00 AM', 'cf_crime:mocodes': '1402 0329 0601', 'cf_crime:part_1_2_val': '2', 'cf_crime:status': 'IC', 'cf_crime:status_desc': 'Invest Cont', 'cf_crime:time_occ': '150', 'cf_loc:area_name': 'Hollywood', 'cf_loc:cross_street': 'HOLLYWOOD                    BL', 'cf_loc:lat': '34.1017', 'cf_loc:location': 'WILTON', 'cf_loc:lon': '-118.3136', 'cf_loc:premis_cd': '203.0', 'cf_loc:premis_desc': 'OTHER BUSINESS', 'cf_loc:rpt_dist_no': '648', 'cf_victim:vict_age': '0', 'cf_victim:vict_descent': 'X', 'cf_victim:vict_sex': 'X', 'row_key': '00_2020_01_06_200604800'}
# {'cf_crime:crm_cd': '626', 'cf_crime:crm_cd_1': '626.0', 'cf_crime:crm_cd_desc': 'INTIMATE PARTNER - SIMPLE ASSAULT', 'cf_crime:date_occ': '01/22/2020 12:00:00 AM', 'cf_crime:date_rptd': '01/23/2020 12:00:00 AM', 'cf_crime:mocodes': '2000 0400 0444 0416 1414', 'cf_crime:part_1_2_val': '2', 'cf_crime:status': 'IC', 'cf_crime:status_desc': 'Invest Cont', 'cf_crime:time_occ': '1600', 'cf_crime:weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)', 'cf_crime:weapon_used_cd': '400.0', 'cf_loc:area_name': 'Hollywood', 'cf_loc:lat': '34.0862', 'cf_loc:location': '5900    GREGORY                      AV', 'cf_loc:lon': '-118.3244', 'cf_loc:premis_cd': '502.0', 'cf_loc:premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)', 'cf_loc:rpt_dist_no': '676', 'cf_victim:vict_age': '33', 'cf_victim:vict_descent': 'H', 'cf_victim:vict_sex': 'F', 'row_key': '00_2020_01_06_200605100'}
#
# DataFrame from Hollywood HBase results:
#   cf_crime:crm_cd cf_crime:crm_cd_1                      cf_crime:crm_cd_desc  \
# 0             510             510.0                          VEHICLE - STOLEN
# 1             510             510.0                          VEHICLE - STOLEN
# 2             330             330.0                     BURGLARY FROM VEHICLE
# 3             745             745.0  VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 4             626             626.0         INTIMATE PARTNER - SIMPLE ASSAULT
#
#         cf_crime:date_occ      cf_crime:date_rptd cf_crime:part_1_2_val  \
# 0  01/09/2020 12:00:00 AM  01/10/2020 12:00:00 AM                     1
# 1  01/13/2020 12:00:00 AM  01/14/2020 12:00:00 AM                     1
# 2  01/15/2020 12:00:00 AM  01/16/2020 12:00:00 AM                     1
# 3  01/18/2020 12:00:00 AM  01/18/2020 12:00:00 AM                     2
# 4  01/22/2020 12:00:00 AM  01/23/2020 12:00:00 AM                     2
#
#   cf_crime:status cf_crime:status_desc cf_crime:time_occ cf_loc:area_name  \
# 0              IC          Invest Cont              1950        Hollywood
# 1              IC          Invest Cont              1830        Hollywood
# 2              IC          Invest Cont                 1        Hollywood
# 3              IC          Invest Cont               150        Hollywood
# 4              IC          Invest Cont              1600        Hollywood
#
#    ...                            cf_loc:premis_desc cf_loc:rpt_dist_no  \
# 0  ...                                        STREET                647
# 1  ...                                        STREET                656
# 2  ...                                        STREET                645
# 3  ...                                OTHER BUSINESS                648
# 4  ...  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)                676
#
#   cf_victim:vict_age                  row_key          cf_crime:mocodes  \
# 0                  0  00_2020_01_06_200604400                       NaN
# 1                  0  00_2020_01_06_200604600                       NaN
# 2                 35  00_2020_01_06_200604700       0344 0358 1300 1609
# 3                  0  00_2020_01_06_200604800            1402 0329 0601
# 4                 33  00_2020_01_06_200605100  2000 0400 0444 0416 1414
#
#   cf_victim:vict_descent cf_victim:vict_sex cf_crime:crm_cd_2  \
# 0                    NaN                NaN               NaN
# 1                    NaN                NaN               NaN
# 2                      O                  M               NaN
# 3                      X                  X             998.0
# 4                      H                  F               NaN
#
#                              cf_crime:weapon_desc cf_crime:weapon_used_cd
# 0                                             NaN                     NaN
# 1                                             NaN                     NaN
# 2                                             NaN                     NaN
# 3                                             NaN                     NaN
# 4  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)                   400.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### C. Victim age and sex for crimes of INTIMATE PARTNER - SIMPLE ASSAULT (exact match)

# %%
def get_intimate_partner_assault_victims(conn, table_name_str, crime_desc="INTIMATE PARTNER - SIMPLE ASSAULT", limit=100):
    if not conn:
        print("No HBase connection.")
        return []

    results = []
    try:
        table = conn.table(table_name_str)
        
        # Columns to retrieve
        columns_to_fetch = [f'{CF_VICTIM}:vict_age', f'{CF_VICTIM}:vict_sex', f'{CF_CRIME}:crm_cd_desc']
        
        # Filter: cf_crime:crm_cd_desc IS 'INTIMATE PARTNER - SIMPLE ASSAULT'
        filter_string = f"SingleColumnValueFilter ('{CF_CRIME}', 'crm_cd_desc', =, 'binary:{crime_desc}')"
        print(f"Scanning for victim info for '{crime_desc}' with filter: {filter_string}")

        for key, data in table.scan(columns=[col.encode('utf-8') for col in columns_to_fetch], 
                                    filter=filter_string, 
                                    limit=limit):
            decoded_data = decode_hbase_row(data)
            decoded_data['row_key'] = key.decode('utf-8')
            results.append(decoded_data)
        print(f"Found {len(results)} victim details for '{crime_desc}' (up to limit {limit}).")

    except Exception as e:
        print(f"Error retrieving victim details for '{crime_desc}': {e}")
    return results

if connection:
    # VERIFY your exact crime description string
    crime_description_exact = "INTIMATE PARTNER - SIMPLE ASSAULT" 
    
    ipa_victim_results = get_intimate_partner_assault_victims(connection, FULL_TABLE_NAME, 
                                                              crime_desc=crime_description_exact, 
                                                              limit=10)
    print("\n--- Intimate Partner Assault Victim Info (Sample) ---")
    for res in ipa_victim_results[:5]:
        print(res)
    df_ipa_victims = pd.DataFrame(ipa_victim_results)
    print("\nDataFrame from Intimate Partner Assault HBase results:")
    display(df_ipa_victims.head())
# Out:
# Scanning for victim info for 'INTIMATE PARTNER - SIMPLE ASSAULT' with filter: SingleColumnValueFilter ('cf_crime', 'crm_cd_desc', =, 'binary:INTIMATE PARTNER - SIMPLE ASSAULT')
# Found 10 victim details for 'INTIMATE PARTNER - SIMPLE ASSAULT' (up to limit 10).
#
# --- Intimate Partner Assault Victim Info (Sample) ---
# {'cf_crime:crm_cd_desc': 'INTIMATE PARTNER - SIMPLE ASSAULT', 'cf_victim:vict_age': '25', 'cf_victim:vict_sex': 'M', 'row_key': '00_2020_01_01_200105000'}
# {'cf_crime:crm_cd_desc': 'INTIMATE PARTNER - SIMPLE ASSAULT', 'cf_victim:vict_age': '20', 'cf_victim:vict_sex': 'F', 'row_key': '00_2020_01_02_200204800'}
# {'cf_crime:crm_cd_desc': 'INTIMATE PARTNER - SIMPLE ASSAULT', 'cf_victim:vict_age': '24', 'cf_victim:vict_sex': 'M', 'row_key': '00_2020_01_05_200504100'}
# {'cf_crime:crm_cd_desc': 'INTIMATE PARTNER - SIMPLE ASSAULT', 'cf_victim:vict_age': '33', 'cf_victim:vict_sex': 'F', 'row_key': '00_2020_01_06_200605100'}
# {'cf_crime:crm_cd_desc': 'INTIMATE PARTNER - SIMPLE ASSAULT', 'cf_victim:vict_age': '23', 'cf_victim:vict_sex': 'F', 'row_key': '00_2020_01_09_200904500'}
#
# DataFrame from Intimate Partner Assault HBase results:
#                 cf_crime:crm_cd_desc cf_victim:vict_age cf_victim:vict_sex  \
# 0  INTIMATE PARTNER - SIMPLE ASSAULT                 25                  M
# 1  INTIMATE PARTNER - SIMPLE ASSAULT                 20                  F
# 2  INTIMATE PARTNER - SIMPLE ASSAULT                 24                  M
# 3  INTIMATE PARTNER - SIMPLE ASSAULT                 33                  F
# 4  INTIMATE PARTNER - SIMPLE ASSAULT                 23                  F
#
#                    row_key
# 0  00_2020_01_01_200105000
# 1  00_2020_01_02_200204800
# 2  00_2020_01_05_200504100
# 3  00_2020_01_06_200605100
# 4  00_2020_01_09_200904500
